# %%
top20name = open("top20_prd_num_name_refined.txt", 'r')
top20 = top20name.readlines()

# %%
prd_info = open("apmall_prd_info.txt", 'r')
inform = prd_info.readlines()

# %%
prd_reviews = open("apmall_prd_reviews.txt", 'r')
reviews = prd_reviews.readlines()

# %%
month_dict = {'2020.02': [], '2020.01': [], '2019.12': [], '2019.11': [], '2019.10': [], 
              '2019.09': [], '2019.08': [], '2019.07': [], '2019.06': [], '2019.05': []}

# %%
for month in month_dict:
    for top in top20:
        top_num = top.split(" | ")[0]
        i = 0
        for review in reviews:
            review_num = review.split(" | ")[0]
            if top_num == review_num and review.split(" | ")[2][:-3] == month:
                i += 1
        month_dict[month].append(i)

# %%
for month in month_dict:
    print(month_dict[month])
# Out:
# [0, 0, 1, 4, 0, 0, 5, 1, 0, 2, 0, 0, 1, 0, 3, 25, 2, 1, 5, 0]
# [0, 0, 15, 20, 0, 12, 13, 12, 8, 7, 13, 10, 11, 8, 8, 81, 22, 13, 6, 6]
# [0, 0, 16, 23, 0, 19, 28, 27, 4, 23, 31, 14, 9, 5, 6, 0, 21, 12, 6, 2]
# [0, 0, 24, 44, 0, 24, 32, 22, 8, 43, 30, 19, 20, 25, 21, 0, 58, 16, 5, 5]
# [2, 0, 13, 3, 0, 19, 7, 7, 5, 2, 2, 5, 3, 10, 2, 0, 0, 8, 7, 4]
# [3, 0, 13, 8, 0, 14, 16, 18, 4, 9, 7, 5, 14, 16, 10, 0, 0, 9, 10, 3]
# [24, 0, 36, 18, 0, 26, 11, 34, 8, 19, 38, 7, 15, 24, 23, 0, 0, 27, 9, 9]
# [54, 10, 32, 20, 0, 50, 6, 20, 9, 15, 6, 14, 25, 17, 8, 0, 0, 11, 12, 14]
# [64, 25, 22, 20, 0, 0, 6, 13, 21, 7, 0, 12, 10, 5, 11, 0, 0, 5, 16, 11]
# [39, 32, 6, 5, 11, 0, 11, 3, 20, 4, 0, 15, 3, 0, 4, 0, 0, 0, 7, 14]

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import seaborn as sns
from matplotlib import font_manager, rc
font_fname = '/Library/Fonts/AppleGothic.ttf'
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family = font_name)
import matplotlib.pyplot as plt

# %%
prd20 = open("top20_prd_num_name_refined.txt", 'r')
prd20 = prd20.readlines()

# %%
prd20list = []
for prd in prd20:
    prd20list.append(prd.split(" | ")[1].rstrip())

# %%
data = {'2020.02': month_dict['2020.02'],
       '2020.01': month_dict['2020.01'],
       '2019.12': month_dict['2019.12'],
       '2019.11': month_dict['2019.11'],
       '2019.10': month_dict['2019.10'],
       '2019.09': month_dict['2019.09'],
       '2019.08': month_dict['2019.08'],
       '2019.07': month_dict['2019.07'],
       '2019.06': month_dict['2019.06'],
       '2019.05': month_dict['2019.05'],
       }

# %%
data_df = DataFrame(data, index=prd20list)

# %%
data_df
# Out:
#                 2020.02  2020.01  2019.12  2019.11  2019.10  2019.09  2019.08  \
# 노세범 미네랄 파우더           0        0        0        0        2        3       24
# 뷰티툴 닦아 쓰는 화장솜         0        0        0        0        0        0        0
# 노세범 미네랄 팩트            1       15       16       24       13       13       36
# 그린티밸런싱크림 세븐데이즈        4       20       23       44        3        8       18
# 뷰티툴 일반 화장솜            0        0        0        0        0        0        0
# 그린 네일                 0       12       19       24       19       14       26
# 투톤 아이브로우 키트           5       13       28       32        7       16       11
# 올리브 리얼 클렌징 티슈         1       12       27       22        7       18       34
# 제주 왕벚꽃 톤업 크림          0        8        4        8        5        4        8
# 국화 여성 청결제             2        7       23       43        2        9       19
# 국화 여성 청결 티슈           0       13       31       30        2        7       38
# 그린티씨드크림               0       10       14       19        5        5        7
# 알로에 리바이탈 수딩젤          1       11        9       20        3       14       15
# 화산송이 모공 클렌징 폼         0        8        5       25       10       16       24
# 글리터브러쉬                3        8        6       21        2       10       23
# 비자 럭키박스 미키 파우치       25       81        0        0        0        0        0
# 올리브 모이스처 핸드크림         2       22       21       58        0        0        0
# 청보리 클렌징 티슈            1       13       12       16        8        9       27
# 그린티씨드에센스인로션           5        6        6        5        7       10        9
# 링클사이언스스팟트리트먼트         0        6        2        5        4        3        9
#
#                 2019.07  2019.06  2019.05
# 노세범 미네랄 파우더          54       64       39
# 뷰티툴 닦아 쓰는 화장솜        10       25       32
# 노세범 미네랄 팩트           32       22        6
# 그린티밸런싱크림 세븐데이즈       20       20        5
# 뷰티툴 일반 화장솜            0        0       11
# 그린 네일                50        0        0
# 투톤 아이브로우 키트           6        6       11
# 올리브 리얼 클렌징 티슈        20       13        3
# 제주 왕벚꽃 톤업 크림          9       21       20
# 국화 여성 청결제            15        7        4
# 국화 여성 청결 티슈           6        0        0
# 그린티씨드크림              14       12       15
# 알로에 리바이탈 수딩젤         25       10        3
# 화산송이 모공 클렌징 폼        17        5        0
# 글리터브러쉬                8       11        4
# 비자 럭키박스 미키 파우치        0        0        0
# 올리브 모이스처 핸드크림         0        0        0
# 청보리 클렌징 티슈           11        5        0
# 그린티씨드에센스인로션          12       16        7
# 링클사이언스스팟트리트먼트        14       11       14

# %%
plt.figure(figsize = (12, 9))
sns.heatmap(data_df, annot=True, fmt="d", cmap="Blues", vmin=0, vmax=50)
plt.show()
